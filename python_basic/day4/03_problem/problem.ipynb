# %% [markdown]
# # 🎯 Day 4 종합 실습: 성적 처리 함수 라이브러리
#
# ## 📋 오늘 배운 내용 총정리
# - ✅ 함수 정의와 호출
# - ✅ 매개변수 (위치, 키워드, 기본값)
# - ✅ 타입 힌트 (기본 타입 + typing 모듈)
# - ✅ 람다 함수와 sorted
# - ✅ 모듈 (random, datetime, json)
# - ✅ *args, **kwargs
#
# ## 🎯 실습 목표
# **오늘 배운 모든 개념을 활용해서 완전한 성적 처리 시스템 만들기!**
#
# ---
#
# ## ⏰ 시간 배분
# - 기초 문제 (1-3번): 15분
# - 응용 문제 (4-7번): 20분
# - 도전 문제 (8-12번): 15분
# - **총 50분**
#
# ## 💡 문제 풀이 팁
# - 기초부터 차근차근!
# - 막히면 힌트 확인
# - 타입 힌트는 꼭 작성하기
# - 테스트 코드로 확인하기
#
# ---

# %% [markdown]
# # 📝 기초 문제 (15분)
#
# ## 문제 1: 평균 계산 함수 ⭐
#
# **요구사항:**
# - 함수명: `calculate_average`
# - 매개변수: `scores` (List[int])
# - 반환값: float (평균 점수)
# - 타입 힌트 필수!
#
# **예시:**
# ```python
# calculate_average([85, 90, 88])  # 87.67
# ```
#
# **힌트:**
# - `from typing import List` 필요
# - 평균 = sum(점수들) / len(점수들)
# - 반환 타입은 `-> float`

# %%
##################################################
# 문제 1: 평균 계산 함수
##################################################

from typing import List

def calculate_average(scores: List[int]) -> float:
    """
    점수 리스트의 평균을 계산합니다.
    
    Args:
        scores: 점수 리스트
    
    Returns:
        float: 평균 점수
    """
    # TODO: 여기에 코드 작성
    pass

# 테스트
print(calculate_average([85, 90, 88]))  # 87.67
print(calculate_average([100, 95, 92, 88]))  # 93.75

# %% [markdown]
# ## 문제 2: 등급 판정 함수 ⭐
#
# **요구사항:**
# - 함수명: `get_grade`
# - 매개변수: `score` (int)
# - 반환값: str (등급)
# - 등급 기준:
#   - 90 이상: "A"
#   - 80 이상: "B"
#   - 70 이상: "C"
#   - 60 이상: "D"
#   - 60 미만: "F"
#
# **예시:**
# ```python
# get_grade(95)  # "A"
# get_grade(82)  # "B"
# get_grade(59)  # "F"
# ```

# %%
##################################################
# 문제 2: 등급 판정 함수
##################################################

def get_grade(score: int) -> str:
    """
    점수에 따른 등급을 반환합니다.
    
    Args:
        score: 점수 (0-100)
    
    Returns:
        str: 등급 (A, B, C, D, F)
    """
    # TODO: 여기에 코드 작성
    # 힌트: if-elif-else 사용
    pass

# 테스트
print(get_grade(95))  # A
print(get_grade(82))  # B
print(get_grade(75))  # C
print(get_grade(65))  # D
print(get_grade(59))  # F

# %% [markdown]
# ## 문제 3: 학생 정보 생성 함수 ⭐
#
# **요구사항:**
# - 함수명: `create_student`
# - 매개변수: `name` (str), `korean` (int), `english` (int), `math` (int)
# - 반환값: Dict[str, any] - 학생 정보 딕셔너리
# - 딕셔너리 구조:
#   ```python
#   {
#       "name": 이름,
#       "korean": 국어,
#       "english": 영어,
#       "math": 수학
#   }
#   ```
#
# **예시:**
# ```python
# create_student("김철수", 85, 90, 88)
# # {"name": "김철수", "korean": 85, "english": 90, "math": 88}
# ```

# %%
##################################################
# 문제 3: 학생 정보 생성 함수
##################################################

from typing import Dict

def create_student(name: str, korean: int, english: int, math: int) -> Dict[str, any]:
    """
    학생 정보 딕셔너리를 생성합니다.
    
    Args:
        name: 학생 이름
        korean: 국어 점수
        english: 영어 점수
        math: 수학 점수
    
    Returns:
        Dict: 학생 정보 딕셔너리
    """
    # TODO: 여기에 코드 작성
    # 힌트: 딕셔너리 생성 후 반환
    pass

# 테스트
student = create_student("김철수", 85, 90, 88)
print(student)
print(student["name"])  # 김철수
print(student["korean"])  # 85

# %% [markdown]
# ---
#
# # 🚀 응용 문제 (20분)
#
# ## 문제 4: 여러 학생 처리 함수 ⭐⭐
#
# **요구사항:**
# - 함수명: `process_students`
# - 매개변수: `students` (List[Dict[str, any]])
# - 반환값: List[Dict[str, any]] - 각 학생에 평균과 등급 추가
# - 추가할 정보:
#   - "average": 평균 점수 (float)
#   - "grade": 등급 (str)
#
# **예시:**
# ```python
# students = [
#     {"name": "김철수", "korean": 85, "english": 90, "math": 88}
# ]
# process_students(students)
# # [{"name": "김철수", "korean": 85, "english": 90, "math": 88, "average": 87.67, "grade": "B"}]
# ```
#
# **힌트:**
# - 문제 1, 2에서 만든 함수 활용!
# - for 문으로 각 학생 처리
# - 원본 딕셔너리에 키 추가

# %%
##################################################
# 문제 4: 여러 학생 처리 함수
##################################################

def process_students(students: List[Dict[str, any]]) -> List[Dict[str, any]]:
    """
    각 학생의 평균과 등급을 계산하여 추가합니다.
    
    Args:
        students: 학생 정보 리스트
    
    Returns:
        List[Dict]: 평균과 등급이 추가된 학생 정보 리스트
    """
    # TODO: 여기에 코드 작성
    # 힌트: 
    # 1. for 문으로 각 학생 순회
    # 2. 국영수 점수를 리스트로 만들기
    # 3. calculate_average()로 평균 계산
    # 4. get_grade()로 등급 계산
    # 5. 학생 딕셔너리에 추가
    pass

# 테스트
students = [
    create_student("김철수", 85, 90, 88),
    create_student("이영희", 92, 88, 95),
    create_student("박민수", 78, 82, 80)
]

result = process_students(students)
for student in result:
    print(f"{student['name']}: 평균 {student['average']:.2f}, 등급 {student['grade']}")

# %% [markdown]
# ## 문제 5: 통계 함수 (Optional 사용) ⭐⭐
#
# **요구사항:**
# - 함수명: `get_stats`
# - 매개변수:
#   - `students` (List[Dict[str, any]])
#   - `subject` (Optional[str] = None) - 특정 과목 선택 (선택적)
# - 반환값: Dict[str, float] - 통계 정보
# - 통계 정보:
#   - "count": 학생 수
#   - "average": 평균
#   - "max": 최고 점수
#   - "min": 최저 점수
#
# **동작:**
# - `subject=None`: 전체 평균 기준 통계
# - `subject="korean"`: 국어 점수 기준 통계
#
# **예시:**
# ```python
# get_stats(students)  # 전체 평균
# get_stats(students, "korean")  # 국어 점수
# ```
#
# **힌트:**
# - `from typing import Optional` 필요
# - if문으로 subject 확인

# %%
##################################################
# 문제 5: 통계 함수 (Optional 사용)
##################################################

from typing import Optional

def get_stats(students: List[Dict[str, any]], subject: Optional[str] = None) -> Dict[str, float]:
    """
    학생들의 통계 정보를 계산합니다.
    
    Args:
        students: 학생 정보 리스트
        subject: 과목명 (None이면 전체 평균)
    
    Returns:
        Dict: 통계 정보 (count, average, max, min)
    """
    # TODO: 여기에 코드 작성
    # 힌트:
    # 1. subject가 None이면 -> "average" 키 사용
    # 2. subject가 있으면 -> 해당 과목 키 사용
    # 3. 리스트 컴프리헨션으로 점수 추출
    # 4. len(), sum(), max(), min() 활용
    pass

# 테스트 (문제 4의 결과 활용)
result = process_students(students)

print("전체 평균 통계:")
stats = get_stats(result)
print(stats)

print("\n국어 점수 통계:")
stats = get_stats(result, "korean")
print(stats)

# %% [markdown]
# ## 문제 6: 학생 검색 함수 ⭐⭐
#
# **요구사항:**
# - 함수명: `find_student`
# - 매개변수: `students` (List[Dict]), `name` (str)
# - 반환값: Optional[Dict] - 찾은 학생 또는 None
#
# **예시:**
# ```python
# find_student(students, "김철수")  # {"name": "김철수", ...}
# find_student(students, "홍길동")  # None
# ```

# %%
##################################################
# 문제 6: 학생 검색 함수
##################################################

def find_student(students: List[Dict[str, any]], name: str) -> Optional[Dict[str, any]]:
    """
    이름으로 학생을 검색합니다.
    
    Args:
        students: 학생 정보 리스트
        name: 검색할 이름
    
    Returns:
        Optional[Dict]: 찾은 학생 정보 또는 None
    """
    # TODO: 여기에 코드 작성
    # 힌트: for 문 + if 문 + return
    pass

# 테스트
found = find_student(students, "김철수")
if found:
    print(f"찾음: {found['name']} - 평균 {found.get('average', 0):.2f}")
else:
    print("못 찾음")

not_found = find_student(students, "홍길동")
print(not_found)  # None

# %% [markdown]
# ## 문제 7: 람다로 학생 정렬 함수 ⭐⭐⭐
#
# **요구사항:**
# - 함수명: `sort_students`
# - 매개변수:
#   - `students` (List[Dict])
#   - `key` (str = "average") - 정렬 기준
#   - `reverse` (bool = False) - 역순 여부
# - 반환값: List[Dict] - 정렬된 학생 리스트
# - 정렬 기준: "average", "name", "korean" 등
#
# **예시:**
# ```python
# sort_students(students, "average", True)  # 평균 높은 순
# sort_students(students, "name")  # 이름 순
# ```
#
# **힌트:**
# - `sorted()` 함수 + `lambda` 사용
# - `lambda x: x[key]`

# %%
##################################################
# 문제 7: 람다로 학생 정렬 함수
##################################################

def sort_students(
    students: List[Dict[str, any]], 
    key: str = "average",
    reverse: bool = False
) -> List[Dict[str, any]]:
    """
    학생들을 지정된 기준으로 정렬합니다.
    
    Args:
        students: 학생 정보 리스트
        key: 정렬 기준 ("average", "name", "korean" 등)
        reverse: 역순 여부 (기본값: False)
    
    Returns:
        List[Dict]: 정렬된 학생 리스트
    """
    # TODO: 여기에 코드 작성
    # 힌트: sorted(students, key=lambda x: x[key], reverse=reverse)
    pass

# 테스트
result = process_students(students)

print("평균 점수 높은 순:")
sorted_by_avg = sort_students(result, "average", True)
for s in sorted_by_avg:
    print(f"{s['name']}: {s['average']:.2f}")

print("\n이름 순:")
sorted_by_name = sort_students(result, "name")
for s in sorted_by_name:
    print(s['name'])

# %% [markdown]
# ---
#
# # 💪 도전 문제 (15분)
#
# ## 문제 8: JSON 저장/불러오기 ⭐⭐⭐
#
# **요구사항:**
#
# ### 8-1. 저장 함수
# - 함수명: `save_to_json`
# - 매개변수: `students` (List[Dict]), `filename` (str)
# - 반환값: None
# - 동작: 학생 데이터를 JSON 파일로 저장
#
# ### 8-2. 불러오기 함수
# - 함수명: `load_from_json`
# - 매개변수: `filename` (str)
# - 반환값: List[Dict]
# - 동작: JSON 파일에서 학생 데이터 불러오기
#
# **힌트:**
# - `json.dump()` / `json.load()` 사용
# - `with open()` 구문 사용

# %%
##################################################
# 문제 8: JSON 저장/불러오기
##################################################

import json

def save_to_json(students: List[Dict], filename: str) -> None:
    """
    학생 데이터를 JSON 파일로 저장합니다.
    
    Args:
        students: 학생 정보 리스트
        filename: 저장할 파일명
    """
    # TODO: 여기에 코드 작성
    # 힌트:
    # with open(filename, 'w', encoding='utf-8') as f:
    #     json.dump(students, f, ensure_ascii=False, indent=2)
    pass

def load_from_json(filename: str) -> List[Dict]:
    """
    JSON 파일에서 학생 데이터를 불러옵니다.
    
    Args:
        filename: 불러올 파일명
    
    Returns:
        List[Dict]: 학생 정보 리스트
    """
    # TODO: 여기에 코드 작성
    # 힌트:
    # with open(filename, 'r', encoding='utf-8') as f:
    #     return json.load(f)
    pass

# 테스트
result = process_students(students)
save_to_json(result, 'students.json')
print("저장 완료!")

loaded = load_from_json('students.json')
print("\n불러온 데이터:")
for s in loaded:
    print(f"{s['name']}: {s['average']:.2f}")

# %% [markdown]
# ## 문제 9: **kwargs로 유연한 학생 생성 ⭐⭐⭐
#
# **요구사항:**
# - 함수명: `create_student_flexible`
# - 매개변수:
#   - `name` (str) - 필수
#   - `**scores` - 과목 점수 (개수 제한 없음)
# - 반환값: Dict[str, any]
# - 동작: 어떤 과목이든 받아서 학생 정보 생성
#
# **예시:**
# ```python
# create_student_flexible("김철수", korean=85, english=90)
# create_student_flexible("이영희", math=95, science=88, history=92)
# ```
#
# **힌트:**
# - `def create_student_flexible(name: str, **scores)`
# - `user = {"name": name}` 먼저 생성
# - `user.update(scores)` 로 점수 추가

# %%
##################################################
# 문제 9: **kwargs로 유연한 학생 생성
##################################################

def create_student_flexible(name: str, **scores) -> Dict[str, any]:
    """
    어떤 과목이든 받아서 학생 정보를 생성합니다.
    
    Args:
        name: 학생 이름
        **scores: 과목명=점수 형태의 가변 인자
    
    Returns:
        Dict: 학생 정보
    """
    # TODO: 여기에 코드 작성
    # 힌트:
    # user = {"name": name}
    # user.update(scores)
    # return user
    pass

# 테스트
student1 = create_student_flexible("김철수", korean=85, english=90)
print(student1)

student2 = create_student_flexible(
    "이영희", 
    math=95, 
    science=88, 
    history=92,
    english=90
)
print(student2)

# %% [markdown]
# ## 문제 10: 딕셔너리 언패킹으로 학생 생성 ⭐⭐⭐
#
# **요구사항:**
# - 딕셔너리 데이터를 `**` 언패킹으로 함수에 전달
# - 기본 정보와 사용자 입력을 병합
#
# **예시:**
# ```python
# # 기본 정보
# default_info = {"grade": 1, "class": "A"}
#
# # 사용자 입력
# student_score = {"name": "김철수", "korean": 85, "math": 90}
#
# # 병합
# student = {**default_info, **student_score}
# # {"grade": 1, "class": "A", "name": "김철수", "korean": 85, "math": 90}
# ```

# %%
##################################################
# 문제 10: 딕셔너리 언패킹
##################################################

# 기본 정보 (모든 학생 공통)
default_info = {
    "grade": 1,
    "class": "A",
    "school": "파이썬고등학교"
}

# TODO 1: 학생 데이터 3개 만들기 (딕셔너리)
student1_data = {
    "name": "김철수",
    "korean": 85,
    "english": 90,
    "math": 88
}

# TODO 2: create_student_flexible 함수에 **언패킹으로 전달
student1 = create_student_flexible(**student1_data)
print(student1)

# TODO 3: 기본 정보와 학생 데이터 병합 (** 언패킹 사용)
# 힌트: {**default_info, **student1_data}
complete_student = None  # 여기에 코드 작성
print(complete_student)

# %% [markdown]
# ## 문제 11: 튜플로 (이름, 평균) 쌍 만들기 ⭐⭐
#
# **요구사항:**
# - 함수명: `get_name_average_pairs`
# - 매개변수: `students` (List[Dict])
# - 반환값: List[tuple] - (이름, 평균) 튜플의 리스트
#
# **예시:**
# ```python
# get_name_average_pairs(students)
# # [("김철수", 87.67), ("이영희", 91.67), ...]
# ```
#
# **힌트:**
# - 리스트 컴프리헨션 사용
# - `[(s["name"], s["average"]) for s in students]`

# %%
##################################################
# 문제 11: 튜플로 (이름, 평균) 쌍 만들기
##################################################

from typing import Tuple

def get_name_average_pairs(students: List[Dict[str, any]]) -> List[Tuple[str, float]]:
    """
    학생들의 (이름, 평균) 튜플 리스트를 반환합니다.
    
    Args:
        students: 학생 정보 리스트 (average 포함)
    
    Returns:
        List[Tuple]: (이름, 평균) 튜플의 리스트
    """
    # TODO: 여기에 코드 작성
    # 힌트: 리스트 컴프리헨션
    pass

# 테스트
result = process_students(students)
pairs = get_name_average_pairs(result)
print(pairs)

# 튜플 언패킹
for name, avg in pairs:
    print(f"{name}: {avg:.2f}")

# %% [markdown]
# ## 문제 12: 전체 시스템 통합 ⭐⭐⭐⭐
#
# **요구사항:**
# 지금까지 만든 모든 함수를 사용해서 완전한 성적표 시스템 만들기!
#
# **단계:**
# 1. JSON 파일에서 학생 데이터 로드 (또는 새로 생성)
# 2. 평균과 등급 계산
# 3. 평균 점수순으로 정렬
# 4. 통계 출력
# 5. 다시 JSON으로 저장
#
# **출력 예시:**
# ```
# === 성적표 시스템 ===
#
# 학생 수: 3명
# 전체 평균: 85.67
# 최고 점수: 91.67
# 최저 점수: 80.00
#
# === 성적 순위 ===
# 1. 이영희: 91.67 (A)
# 2. 김철수: 87.67 (B)
# 3. 박민수: 80.00 (B)
# ```

# %%
##################################################
# 문제 12: 전체 시스템 통합
##################################################

def main():
    """
    성적표 시스템 메인 함수
    """
    print("=== 성적표 시스템 ===")
    print()
    
    # TODO 1: 학생 데이터 생성 (또는 JSON에서 로드)
    students = [
        create_student("김철수", 85, 90, 88),
        create_student("이영희", 92, 88, 95),
        create_student("박민수", 78, 82, 80)
    ]
    
    # TODO 2: 평균과 등급 계산
    # 힌트: process_students() 사용
    
    # TODO 3: 통계 출력
    # 힌트: get_stats() 사용
    
    # TODO 4: 정렬 (평균 높은 순)
    # 힌트: sort_students() 사용
    
    # TODO 5: 순위 출력
    # enumerate로 순위 매기기
    
    # TODO 6: JSON 저장
    # 힌트: save_to_json() 사용
    
    pass

# 실행
main()

# %% [markdown]
# ---
#
# # 🎉 축하합니다!
#
# ## 5일간의 기초 과정을 완료하셨습니다!
#
# ### 📚 배운 내용 정리
#
# **Day 1: Python 시작 & 기본 자료형**
# - ✅ Python 설치 및 개발 환경
# - ✅ 변수, 숫자형, 문자열
# - ✅ 입출력 (print, input)
# - ✅ f-string 포맷팅
#
# **Day 2: 자료형 완성**
# - ✅ 리스트 (생성, 수정, 메서드)
# - ✅ 딕셔너리 (CRUD, 메서드)
# - ✅ 딕셔너리 언패킹 (**)
# - ✅ 튜플, 집합, None
#
# **Day 3: 흐름 제어**
# - ✅ if-elif-else 조건문
# - ✅ for 문, while 문
# - ✅ 딕셔너리 순회 (items)
# - ✅ 리스트 컴프리헨션
# - ✅ enumerate, range
#
# **Day 4: 함수와 모듈 (오늘!)**
# - ✅ 함수 정의와 호출
# - ✅ 매개변수 (위치, 키워드, 기본값)
# - ✅ 타입 힌트 (typing 모듈)
# - ✅ 람다 함수
# - ✅ 모듈 (random, datetime, json)
# - ✅ *args, **kwargs
#
# **Day 5 예고: 클래스와 예외 처리**
# - 클래스와 객체 (FastAPI Pydantic 준비!)
# - 예외 처리 (try-except-raise)
# - 종합 프로젝트
#
# ---
#
# ## 🚀 다음 단계는?
#
# **Week 2: FastAPI 응용 과정**
# - 웹 개념과 REST API
# - FastAPI 기초
# - Pydantic 모델
# - 데이터베이스 연동
#
# **오늘 배운 내용이 FastAPI에서 어떻게 쓰일까요?**
# - 함수 → API 엔드포인트
# - 타입 힌트 → 자동 검증
# - 딕셔너리 → JSON 응답
# - 클래스 → Pydantic 모델
#
# **수고하셨습니다! 🎊**
#
# ---

# %% [markdown]
# ## 💬 질의응답 & 피드백
#
# **어려웠던 부분:**
# -
#
# **재미있었던 부분:**
# -
#
# **더 알고 싶은 내용:**
# -
#
# ---
