# %% [markdown]
# # 🎯 Day 3 종합 실습: 상품 관리 프로그램 (CLI 버전)
#
# ## 📋 프로젝트 개요
# 오늘 배운 **클래스**, **함수**, **예외 처리**를 모두 활용하여 상품 관리 프로그램을 만들어봅니다!
#
# ### 사용할 개념
# - ✅ 클래스와 객체 (Product 클래스)
# - ✅ 함수 정의와 호출
# - ✅ 리스트로 여러 객체 관리
# - ✅ 예외 처리 (try-except, raise)
# - ✅ 타입 힌트
#
# ### 난이도 구성
# - 🟢 **기초 (1~3)**: 클래스 만들기, 기본 CRUD
# - 🟡 **응용 (4~6)**: 검색, 삭제, 예외 처리
# - 🔴 **도전 (7~8)**: 재고 관리, 메인 프로그램
#
# ---
#
# **💡 TIP:**
# - 위에서부터 순서대로 풀어가세요
# - 각 문제를 완성한 후 테스트하고 다음으로!
# - 막히면 힌트를 참고하세요
# - 완성된 함수는 다음 문제에서 재사용하세요
#
# ---

# %% [markdown]
# ## 🟢 기초 1: Product 클래스 구현
#
# ### 요구사항
# 상품 정보를 담는 `Product` 클래스를 만드세요.
#
# **속성:**
# - `name` (str): 상품명
# - `price` (int): 가격
# - `stock` (int): 재고
#
# **메서드:**
# - `__init__(self, name: str, price: int, stock: int)`: 초기화
# - `get_info(self) -> str`: 상품 정보를 문자열로 반환
#   - 형식: `"상품명: 노트북, 가격: 1500000원, 재고: 5개"`
#
# **힌트:**
# ```python
# class Product:
#     def __init__(self, ...):
#         self.name = ...
#
#     def get_info(self) -> str:
#         return f"상품명: {self.name}, ..."
# ```

# %%
##################################################
# 기초 1: Product 클래스 구현
##################################################

# 여기에 Product 클래스를 작성하세요


# 테스트 코드
print("=== 기초 1 테스트 ===")
laptop = Product("노트북", 1500000, 5)
print(laptop.get_info())
# 예상 출력: 상품명: 노트북, 가격: 1500000원, 재고: 5개

# %% [markdown]
# ## 🟢 기초 2: 상품 추가 함수 구현
#
# ### 요구사항
# `add_product(products)` 함수를 만드세요.
#
# **동작:**
# 1. 사용자에게 상품명, 가격, 재고를 `input()`으로 입력받기
# 2. `int()`로 가격과 재고를 숫자로 변환
# 3. `Product` 객체를 생성하고 `products` 리스트에 추가
# 4. `"'{상품명}' 상품이 추가되었습니다"` 출력
#
# **힌트:**
# ```python
# def add_product(products: list) -> None:
#     name = input("상품명: ")
#     price = int(input("가격: "))
#     ...
#     product = Product(name, price, stock)
#     products.append(product)
# ```

# %%
##################################################
# 기초 2: 상품 추가 함수 구현
##################################################

def add_product(products: list) -> None:
    """
    사용자에게 상품명, 가격, 재고를 입력받아
    Product 객체를 생성하고 products 리스트에 추가
    """
    # 여기에 코드 작성
    pass


# 테스트 코드
print("\n=== 기초 2 테스트 ===")
products = []
# add_product(products)  # 주석 해제하고 테스트
# 입력 예시: 마우스, 30000, 10
print(f"현재 상품 수: {len(products)}개")

# %% [markdown]
# ## 🟢 기초 3: 전체 상품 조회 함수 구현
#
# ### 요구사항
# `show_all_products(products)` 함수를 만드세요.
#
# **동작:**
# 1. `products` 리스트가 비어있으면 `"등록된 상품이 없습니다"` 출력
# 2. 그렇지 않으면 모든 상품의 정보를 출력
# 3. 형식: `"1. 상품명: 노트북, 가격: 1500000원, 재고: 5개"`
#
# **힌트:**
# ```python
# def show_all_products(products: list) -> None:
#     if not products:  # 또는 len(products) == 0
#         print("등록된 상품이 없습니다")
#         return
#
#     for i, product in enumerate(products, 1):
#         print(f"{i}. {product.get_info()}")
# ```

# %%
##################################################
# 기초 3: 전체 상품 조회 함수 구현
##################################################

def show_all_products(products: list) -> None:
    """
    products 리스트의 모든 상품 정보를 출력
    상품이 없으면 "등록된 상품이 없습니다" 출력
    """
    # 여기에 코드 작성
    pass


# 테스트 코드
print("\n=== 기초 3 테스트 ===")
test_products = [
    Product("노트북", 1500000, 5),
    Product("마우스", 30000, 10),
    Product("키보드", 80000, 15)
]
show_all_products(test_products)

print("\n빈 리스트 테스트:")
show_all_products([])

# %% [markdown]
# ---
#
# ## 🟡 응용 1: 상품 검색 함수 구현
#
# ### 요구사항
# `search_product(products, name)` 함수를 만드세요.
#
# **동작:**
# - 이름으로 상품을 검색해서 찾으면 `Product` 객체 반환
# - 못 찾으면 `None` 반환
#
# **힌트:**
# ```python
# def search_product(products: list, name: str) -> Product | None:
#     for product in products:
#         if product.name == name:
#             return product
#     return None
# ```
#
# **타입 힌트 참고:**
# - `Product | None`은 "Product 또는 None"을 의미 (Python 3.10+)
# - 구버전: `Optional[Product]` (from typing import Optional)

# %%
##################################################
# 응용 1: 상품 검색 함수 구현
##################################################

def search_product(products: list, name: str):
    """
    이름으로 상품을 검색해서 찾으면 Product 객체 반환
    없으면 None 반환
    
    힌트: for문 + if문, 찾으면 return
    """
    # 여기에 코드 작성
    pass


# 테스트 코드
print("\n=== 응용 1 테스트 ===")
test_products = [
    Product("노트북", 1500000, 5),
    Product("마우스", 30000, 10)
]

# 찾는 경우
found = search_product(test_products, "마우스")
if found:
    print(f"찾음: {found.get_info()}")

# 못 찾는 경우
not_found = search_product(test_products, "키보드")
if not_found is None:
    print("못 찾음: None")

# %% [markdown]
# ## 🟡 응용 2: 상품 삭제 함수 구현
#
# ### 요구사항
# `delete_product(products, name)` 함수를 만드세요.
#
# **동작:**
# 1. `search_product()` 함수를 사용해서 상품을 찾기
# 2. 찾았으면 `products.remove()`로 삭제하고 `"상품이 삭제되었습니다"` 출력
# 3. 못 찾았으면 `"해당 상품이 없습니다"` 출력
#
# **힌트:**
# ```python
# def delete_product(products: list, name: str) -> None:
#     product = search_product(products, name)
#     if product:
#         products.remove(product)
#         print("상품이 삭제되었습니다")
#     else:
#         print("해당 상품이 없습니다")
# ```

# %%
##################################################
# 응용 2: 상품 삭제 함수 구현
##################################################

def delete_product(products: list, name: str) -> None:
    """
    이름으로 상품을 찾아서 삭제
    없으면 "해당 상품이 없습니다" 메시지 출력
    
    힌트: search_product 함수 재사용, remove 메서드
    """
    # 여기에 코드 작성
    pass


# 테스트 코드
print("\n=== 응용 2 테스트 ===")
test_products = [
    Product("노트북", 1500000, 5),
    Product("마우스", 30000, 10)
]

print(f"삭제 전: {len(test_products)}개")
delete_product(test_products, "마우스")
print(f"삭제 후: {len(test_products)}개")

delete_product(test_products, "키보드")  # 없는 상품

# %% [markdown]
# ## 🟡 응용 3: 가격 입력 검증 함수 구현
#
# ### 요구사항
# `get_valid_price()` 함수를 만드세요.
#
# **동작:**
# 1. 사용자에게 가격을 입력받되, 숫자가 아니면 다시 입력받기 (`ValueError` 처리)
# 2. 0 이하면 `raise ValueError("가격은 0보다 커야 합니다")`
# 3. 정상이면 `int`로 반환
#
# **힌트:**
# ```python
# def get_valid_price() -> int:
#     while True:
#         try:
#             price = int(input("가격: "))
#             if price <= 0:
#                 raise ValueError("가격은 0보다 커야 합니다")
#             return price
#         except ValueError as e:
#             print(f"오류: {e}")
#             print("다시 입력해주세요")
# ```

# %%
##################################################
# 응용 3: 가격 입력 검증 함수 구현
##################################################

def get_valid_price() -> int:
    """
    유효한 가격 입력받기 (예외 처리 포함)
    
    Returns:
        유효한 가격 (양수)
    
    Raises:
        ValueError: 0 이하의 가격인 경우
    
    힌트: while + try-except + raise
    """
    # 여기에 코드 작성
    pass


# 테스트 코드
print("\n=== 응용 3 테스트 ===")
# price = get_valid_price()  # 주석 해제하고 테스트
# print(f"입력된 가격: {price}원")
# 테스트 입력 예시: "abc" → 오류, "-100" → 오류, "5000" → 성공

# %% [markdown]
# ---
#
# ## 🔴 도전 1: 재고 관리 기능 추가
#
# ### 요구사항
# `Product` 클래스에 다음 메서드를 추가하세요.
#
# **1. add_stock(self, amount: int) -> None**
# - 재고를 `amount`만큼 증가
# - `"재고 {amount}개 추가됨. 현재 재고: {self.stock}개"` 출력
#
# **2. reduce_stock(self, amount: int) -> None**
# - 재고를 `amount`만큼 감소
# - 재고가 부족하면 `raise ValueError("재고 부족! 현재: {self.stock}개")`
# - 성공하면 `"재고 {amount}개 감소됨. 현재 재고: {self.stock}개"` 출력
#
# **힌트:**
# ```python
# # Product 클래스에 추가
# def add_stock(self, amount: int) -> None:
#     self.stock += amount
#     print(f"재고 {amount}개 추가됨. 현재 재고: {self.stock}개")
#
# def reduce_stock(self, amount: int) -> None:
#     if self.stock < amount:
#         raise ValueError(f"재고 부족! 현재: {self.stock}개")
#     self.stock -= amount
#     print(f"재고 {amount}개 감소됨. 현재 재고: {self.stock}개")
# ```

# %%
##################################################
# 도전 1: 재고 관리 기능 추가
##################################################

# 위에서 만든 Product 클래스에 메서드를 추가하거나
# 여기서 다시 정의하세요 (메서드 포함)

class Product:
    def __init__(self, name: str, price: int, stock: int) -> None:
        self.name = name
        self.price = price
        self.stock = stock
    
    def get_info(self) -> str:
        return f"상품명: {self.name}, 가격: {self.price}원, 재고: {self.stock}개"
    
    # 여기에 add_stock 메서드 추가
    
    # 여기에 reduce_stock 메서드 추가


# 테스트 코드
print("\n=== 도전 1 테스트 ===")
product = Product("마우스", 30000, 10)
print(product.get_info())

# product.add_stock(5)  # 주석 해제하고 테스트
# print(product.get_info())

# product.reduce_stock(3)  # 주석 해제하고 테스트
# print(product.get_info())

# try:
#     product.reduce_stock(20)  # 재고 부족!
# except ValueError as e:
#     print(f"에러: {e}")

# %% [markdown]
# ## 🔴 도전 2: 메인 프로그램 완성하기
#
# ### 요구사항
# `main()` 함수를 만들어서 아래 메뉴를 구현하세요.
#
# ```
# === 상품 관리 프로그램 ===
# 1. 상품 추가
# 2. 전체 조회
# 3. 상품 검색
# 4. 상품 삭제
# 5. 종료
# 선택:
# ```
#
# **힌트:**
# ```python
# def main():
#     products = []
#
#     while True:
#         print("\n=== 상품 관리 프로그램 ===")
#         print("1. 상품 추가")
#         print("2. 전체 조회")
#         print("3. 상품 검색")
#         print("4. 상품 삭제")
#         print("5. 종료")
#
#         choice = input("선택: ")
#
#         if choice == "1":
#             add_product(products)
#         elif choice == "2":
#             show_all_products(products)
#         elif choice == "3":
#             name = input("검색할 상품명: ")
#             product = search_product(products, name)
#             if product:
#                 print(product.get_info())
#             else:
#                 print("상품을 찾을 수 없습니다")
#         elif choice == "4":
#             name = input("삭제할 상품명: ")
#             delete_product(products, name)
#         elif choice == "5":
#             print("프로그램을 종료합니다")
#             break
#         else:
#             print("잘못된 선택입니다")
# ```

# %%
##################################################
# 도전 2: 메인 프로그램 완성하기
##################################################

def main():
    """메인 프로그램"""
    # 여기에 코드 작성
    pass


# 프로그램 실행
if __name__ == "__main__":
    # main()  # 주석 해제하고 실행
    print("main() 함수를 완성하고 주석을 해제하세요!")

# %% [markdown]
# ---
#
# ## 🎉 종합 실습 완료!
#
# ### 체크리스트
# - ✅ Product 클래스 구현
# - ✅ 상품 추가 함수
# - ✅ 전체 조회 함수
# - ✅ 상품 검색 함수
# - ✅ 상품 삭제 함수
# - ✅ 가격 입력 검증
# - ✅ 재고 관리 기능
# - ✅ 메인 프로그램
#
# ### 배운 내용 정리
# 1. **클래스**: 데이터와 기능을 하나로 묶기
# 2. **함수**: 코드 재사용과 구조화
# 3. **리스트**: 여러 객체 관리
# 4. **예외 처리**: 안전한 프로그램 만들기
# 5. **타입 힌트**: 명확한 코드 작성
#
# ### 추가 도전 과제 (선택)
# 시간이 남으면 다음 기능을 추가해보세요:
# - 📝 가격 범위로 상품 필터링
# - 💰 총 재고 가치 계산 (가격 × 재고)
# - 📊 재고가 적은 상품 알림 (5개 이하)
# - 💾 JSON 파일로 저장/불러오기
#
# ---
#
# **💡 다음 단계:**
# - 응용 과정에서 이 프로그램을 **FastAPI**로 변환할 거예요!
# - CLI → Web API로 진화! 🚀
