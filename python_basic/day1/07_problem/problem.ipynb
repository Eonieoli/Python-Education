# %% [markdown]
# # 🎯 Day 1 종합 실습: 텍스트 처리 프로그램
#
# ## 📚 오늘 배운 내용 복습
# - ✅ print()와 input()
# - ✅ 변수와 타입 (str, int, float, bool)
# - ✅ 숫자 연산 (+, -, *, /, //, %, **)
# - ✅ 문자열 조작 (인덱싱, 슬라이싱, f-string, 메서드)
# - ✅ Boolean과 비교 연산자
#
# ## ⏰ 시간 배분
# - **기초 문제** (15분): 1-4번
# - **응용 문제** (20분): 5-8번
# - **도전 문제** (15분): 9-10번
#
# **💡 막히면 언제든지 손들어주세요!**
#
# ---

# %% [markdown]
# ## 📝 기초 문제 (15분)
#
# ### 문제 1: 사칙연산 계산기
# 두 숫자를 입력받아 사칙연산 결과를 모두 출력하세요.
#
# **출력 예시:**
# ```
# 첫 번째 숫자: 10
# 두 번째 숫자: 3
#
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30
# 10 / 3 = 3.33
# ```

# %%
# 문제 1: 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 2: 자기소개 출력
# 이름과 나이를 입력받아 f-string으로 자기소개를 출력하세요.
#
# **출력 예시:**
# ```
# 이름을 입력하세요: 김철수
# 나이를 입력하세요: 25
#
# 안녕하세요! 제 이름은 김철수이고, 25살입니다.
# 내년이면 26살이 되네요!
# ```

# %%
# 문제 2: 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 3: 주민번호 앞자리 추출
# 주민번호를 입력받아 앞 6자리(생년월일)만 추출하세요.
#
# **힌트:** 슬라이싱 사용 `[start:end]`
#
# **출력 예시:**
# ```
# 주민번호를 입력하세요: 991231-1234567
# 생년월일: 991231
# ```

# %%
# 문제 3: 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 4: 문자열 거꾸로 출력
# 문자열을 입력받아 거꾸로 출력하세요.
#
# **힌트:** `[::-1]` 사용
#
# **출력 예시:**
# ```
# 문자열을 입력하세요: Python
# 거꾸로: nohtyP
# ```

# %%
# 문제 4: 여기에 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 🚀 응용 문제 (20분)
#
# ### 문제 5: 영수증 만들기
# 여러 줄 문자열(`"""`)을 사용해서 영수증을 만드세요.
#
# **출력 예시:**
# ```
# 상품명을 입력하세요: 노트북
# 가격을 입력하세요: 1500000
# 수량을 입력하세요: 2
#
# ========== 영수증 ==========
# 상품명: 노트북
# 단가: 1,500,000원
# 수량: 2개
# ---------------------------
# 총액: 3,000,000원
# ===========================
# ```
#
# **힌트:**
# - 천 단위 구분: `f"{price:,}"`
# - 여러 줄 출력: `print("""...""")` 또는 `\n` 사용

# %%
# 문제 5: 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 6: 이메일 유효성 검사
# 이메일 주소를 입력받아 간단한 유효성 검사를 하세요.
#
# **검사 조건:**
# 1. `@`가 포함되어 있는가?
# 2. `.com`으로 끝나는가?
#
# **힌트:** `in` 연산자, `endswith()` 메서드 사용
#
# **출력 예시:**
# ```
# 이메일을 입력하세요: user@example.com
# @ 포함: True
# .com으로 끝남: True
# 유효한 이메일입니다! ✅
# ```
#
# ```
# 이메일을 입력하세요: invalid-email
# @ 포함: False
# .com으로 끝남: False
# 유효하지 않은 이메일입니다! ❌
# ```

# %%
# 문제 6: 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 7: CSV 데이터 파싱
# CSV 형식의 문자열을 입력받아 각 항목을 분리하여 출력하세요.
#
# **힌트:** `split(',')` 메서드 사용
#
# **출력 예시:**
# ```
# CSV 데이터를 입력하세요: 김철수,25,student@example.com
#
# 이름: 김철수
# 나이: 25
# 이메일: student@example.com
# ```

# %%
# 문제 7: 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 8: 단어 개수 세기
# 문장을 입력받아 단어 개수를 세세요.
#
# **힌트:**
# - `split()` 메서드로 공백 기준 분리
# - `len()` 함수로 개수 세기
#
# **출력 예시:**
# ```
# 문장을 입력하세요: Python is awesome and fun to learn
#
# 입력한 문장: "Python is awesome and fun to learn"
# 단어 개수: 7개
# 문장 길이: 35글자
# ```

# %%
# 문제 8: 여기에 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 💪 도전 문제 (15분)
#
# ### 문제 9: 온도 변환기
# 입력받은 온도를 자동으로 섭씨 ↔ 화씨 변환하세요.
#
# **변환 공식:**
# - 섭씨 → 화씨: `F = C × 9/5 + 32`
# - 화씨 → 섭씨: `C = (F - 32) × 5/9`
#
# **힌트:**
# - 마지막 글자가 'C'인지 'F'인지 확인: `endswith()` 또는 `[-1]`
# - 숫자 부분만 추출: `[:-1]`
# - 소수점 1자리까지만: `f"{value:.1f}"`
#
# **출력 예시:**
# ```
# 온도를 입력하세요: 25C
# 25.0°C = 77.0°F
# ```
#
# ```
# 온도를 입력하세요: 77F
# 77.0°F = 25.0°C
# ```

# %%
# 문제 9: 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 10: 비밀번호 강도 체크
# 비밀번호를 입력받아 강도를 체크하세요.
#
# **체크 항목:**
# 1. 길이가 8자 이상인가? (`len()`)
# 2. 대문자가 포함되어 있는가? (문자열 메서드 찾아보기!)
# 3. 숫자가 포함되어 있는가? (문자열 메서드 찾아보기!)
#
# **강도 판정:**
# - 3개 모두 만족: "강력함 💪"
# - 2개 만족: "보통 👍"
# - 1개 이하: "약함 ⚠️"
#
# **힌트:**
# - 대문자 체크: `password != password.lower()`
# - 숫자 체크: `password != password.replace('0','').replace('1','')...` 또는 다른 방법
#
# **출력 예시:**
# ```
# 비밀번호를 입력하세요: MyPass123
#
# ✅ 길이 충족 (9자)
# ✅ 대문자 포함
# ✅ 숫자 포함
#
# 비밀번호 강도: 강력함 💪
# ```
#
# ```
# 비밀번호를 입력하세요: weak
#
# ❌ 길이 부족 (4자)
# ❌ 대문자 없음
# ❌ 숫자 없음
#
# 비밀번호 강도: 약함 ⚠️
# ```

# %%
# 문제 10: 여기에 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 🎉 수고하셨습니다!
#
# ### 오늘 배운 핵심 내용
# - ✅ 입출력 (print, input)
# - ✅ 변수와 타입
# - ✅ 숫자 연산
# - ✅ 문자열 처리
# - ✅ Boolean과 조건
#
# ### 다음 시간 예고
# 내일은 **리스트와 딕셔너리**를 배울 거예요!
# FastAPI에서 정말 중요한 자료형이니까 기대하세요! 😊
#
# **💡 궁금한 점이 있으면 언제든 질문해주세요!**
#
# ---
