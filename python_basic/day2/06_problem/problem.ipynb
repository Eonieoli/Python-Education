# %% [markdown]
# # 🎯 Day 2 종합 실습: 학생 성적 관리 시스템
#
# ## 📋 실습 개요
# 오늘 배운 **리스트, 딕셔너리, 튜플, 집합**을 모두 활용하여
# 학생 성적 관리 시스템을 만들어봅시다!
#
# ## ⏰ 시간 배분
# - **기초 문제** (15분): 1~3번
# - **응용 문제** (15분): 4~7번
# - **도전 문제** (10분): 8~10번
#
# ## 💡 Tip
# - 막히면 손들고 질문하세요!
# - 기초 문제부터 차근차근 풀어보세요
# - 완성된 코드는 실행해서 확인하세요
#
# ---

# %% [markdown]
# ## 📝 기초 문제 (15분)
#
# ### 문제 1: 학생 정보 딕셔너리 3개 만들기
#
# 다음 정보를 가진 학생 딕셔너리 3개를 만드세요:
# - 키: `"name"`, `"korean"`, `"english"`, `"math"`
#
# **학생 정보:**
# - 철수: 국어 85, 영어 90, 수학 88
# - 영희: 국어 92, 영어 88, 수학 95
# - 민수: 국어 78, 영어 82, 수학 80

# %%
# 문제 1: 여기에 코드를 작성하세요

student1 = 

student2 = 

student3 = 

# 확인
print(student1)
print(student2)
print(student3)

# %% [markdown]
# ### 문제 2: 학생들을 리스트에 추가하기
#
# 위에서 만든 3개의 학생 딕셔너리를
# `students`라는 리스트에 담으세요.

# %%
# 문제 2: 여기에 코드를 작성하세요

students = 

# 확인
print(students)
print(f"총 학생 수: {len(students)}명")

# %% [markdown]
# ### 문제 3: 모든 학생 정보 출력하기 (for문 사용)
#
# for문을 사용하여 각 학생의 이름과 점수를 다음 형식으로 출력하세요:
# ```
# 철수: 국어 85, 영어 90, 수학 88
# 영희: 국어 92, 영어 88, 수학 95
# 민수: 국어 78, 영어 82, 수학 80
# ```

# %%
# 문제 3: 여기에 코드를 작성하세요

for student in students:
    # 여기에 print 문 작성
    pass

# %% [markdown]
# ---
#
# ## 🚀 응용 문제 (15분)
#
# ### 문제 4: 특정 학생 찾기 (이름으로 검색)
#
# "영희" 학생을 찾아서 그 학생의 정보를 출력하세요.
# - for문 사용
# - 학생을 찾으면 출력하고 `break`로 중단

# %%
# 문제 4: 여기에 코드를 작성하세요

search_name = "영희"

for student in students:
    # 여기에 코드 작성
    pass

# %% [markdown]
# ### 문제 5: 각 학생의 평균 점수 계산하기
#
# 각 학생의 3과목 평균을 계산하고 출력하세요.
# ```
# 철수의 평균: 87.7점
# 영희의 평균: 91.7점
# 민수의 평균: 80.0점
# ```

# %%
# 문제 5: 여기에 코드를 작성하세요

for student in students:
    # 평균 계산
    average = 
    
    # 출력
    print(f"{student['name']}의 평균: {average:.1f}점")

# %% [markdown]
# ### 문제 6: 80점 이상 학생만 필터링
#
# 3과목 평균이 80점 이상인 학생들만 모아서
# 새로운 리스트 `high_achievers`를 만드세요.

# %%
# 문제 6: 여기에 코드를 작성하세요

high_achievers = []

for student in students:
    average = (student["korean"] + student["english"] + student["math"]) / 3
    
    # 평균이 80점 이상이면 추가
    if average >= 80:
        # 여기에 코드 작성
        pass

# 확인
print("우등생 명단:")
for student in high_achievers:
    print(student["name"])

# %% [markdown]
# ### 문제 7: 과목별 전체 평균 계산
#
# 전체 학생의 과목별 평균을 계산하세요:
# - 국어 평균
# - 영어 평균
# - 수학 평균

# %%
# 문제 7: 여기에 코드를 작성하세요

# 방법 1: 직접 합산
korean_total = 0
english_total = 0
math_total = 0

for student in students:
    # 여기에 코드 작성
    pass

korean_avg = korean_total / len(students)
english_avg = english_total / len(students)
math_avg = math_total / len(students)

print(f"국어 평균: {korean_avg:.1f}점")
print(f"영어 평균: {english_avg:.1f}점")
print(f"수학 평균: {math_avg:.1f}점")

# %% [markdown]
# ---
#
# ## 🏆 도전 문제 (10분)
#
# ### 문제 8: 딕셔너리 언패킹으로 학생 생성 함수 만들기
#
# 딕셔너리 언패킹(`**`)을 사용하여 학생을 생성하는 함수를 만드세요.
#
# **힌트:**
# ```python
# def create_student(name, korean, english, math):
#     return {"name": name, "korean": korean,
#             "english": english, "math": math}
#
# student_data = {"name": "지수", "korean": 90, "english": 85, "math": 92}
# student = create_student(**student_data)
# ```

# %%
# 문제 8: 여기에 코드를 작성하세요

def create_student(name, korean, english, math):
    # 여기에 코드 작성
    pass

# 테스트
student_data = {"name": "지수", "korean": 90, "english": 85, "math": 92}
new_student = create_student(**student_data)
print(new_student)

# %% [markdown]
# ### 문제 9: 딕셔너리 병합으로 기본 정보 추가
#
# 딕셔너리 언패킹을 사용하여 기본 정보를 추가하세요.
#
# **요구사항:**
# - 기본 정보: `{"grade": 1, "class": "A"}`
# - 학생 점수: `{"name": "철수", "score": 85}`
# - 두 딕셔너리를 병합

# %%
# 문제 9: 여기에 코드를 작성하세요

default_info = {"grade": 1, "class": "A"}
student_score = {"name": "철수", "score": 85}

# 딕셔너리 병합 (** 사용)
student = 

# 확인
print(student)
# 출력: {'grade': 1, 'class': 'A', 'name': '철수', 'score': 85}

# %% [markdown]
# ### 문제 10: 튜플로 (이름, 평균) 쌍 만들기
#
# 각 학생의 (이름, 평균점수)를 튜플로 만들어
# 리스트에 저장하세요.
#
# **출력 예시:**
# ```python
# [('철수', 87.7), ('영희', 91.7), ('민수', 80.0)]
# ```

# %%
# 문제 10: 여기에 코드를 작성하세요

name_avg_list = []

for student in students:
    # 평균 계산
    average = (student["korean"] + student["english"] + student["math"]) / 3
    
    # (이름, 평균) 튜플 만들어서 추가
    # 여기에 코드 작성
    pass

# 확인
print(name_avg_list)

# %% [markdown]
# ---
#
# ## 🎁 보너스 문제 (시간 남으면)
#
# ### 보너스 1: 최고 점수 학생 찾기
#
# 평균이 가장 높은 학생을 찾아 출력하세요.

# %%
# 보너스 1: 여기에 코드를 작성하세요

max_avg = 0
top_student = None

for student in students:
    average = (student["korean"] + student["english"] + student["math"]) / 3
    
    # 최고 점수 갱신
    # 여기에 코드 작성
    pass

print(f"최고 점수 학생: {top_student['name']} ({max_avg:.1f}점)")

# %% [markdown]
# ### 보너스 2: 집합으로 과목 목록 만들기
#
# 모든 학생의 과목명을 집합으로 수집하세요.
# ("name"은 제외)

# %%
# 보너스 2: 여기에 코드를 작성하세요

subjects = set()

for student in students:
    for key in student.keys():
        if key != "name":
            # 여기에 코드 작성
            pass

print("과목 목록:", subjects)

# %% [markdown]
# ---
#
# ## 🎉 수고하셨습니다!
#
# ### 오늘 배운 내용 정리
#
# ✅ **리스트**
# - 생성, 인덱싱, 슬라이싱
# - 추가(append), 삭제(remove, pop)
# - 메서드(sort, reverse, count)
# - 내장 함수(sum, max, min, len)
#
# ✅ **딕셔너리**
# - Key-Value 개념
# - CRUD (생성, 조회, 수정, 삭제)
# - 메서드(keys, values, items, get)
# - 언패킹(`**`)
#
# ✅ **튜플**
# - 수정 불가능한 리스트
# - 언패킹
#
# ✅ **집합**
# - 중복 제거
# - 순서 없음
#
# ✅ **None**
# - "값 없음" 표현
#
# ### 💪 다음 시간 예고
# - Day 3: if, for, while 제어문
# - 리스트 컴프리헨션
#
# ---
